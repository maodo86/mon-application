# %% [markdown]
# <b> But de l'exerice </b>
#
# L'objectif est d'apprendre à utiliser l'API restcountries, qui permet d'obtenir des données sur tous les Pays du monde. <br>
#
# 1) Faites une lecture rapide de la documentation de l'API : https://restcountries.eu/ <br>
# 2) Via requests.get et .content, tester le bon fonctionnement de l'API en requetant https://restcountries.eu/rest/v2/all. Récupérez vous bien des données ? Quel est code réponse de l'API ? <br>
# 3) Enregistrer le contenu de l'API dans la variable data. reformater data au format json grace à json.loads <br>
# 4) Créer un tableau pandas appelé dataSet, à partir de data et la fonction json_normalize. Visualisez les données. <br>
# 5) il y a beaucoup trop de données...nous allons simplifier cela. Refaire de même process d'appel mais cette fois avec cette API : https://restcountries.eu/rest/v2/alpha?codes=FRA . Il ne doit maintenir y avoir qu'une seul ligne correspondant aux infos sur la France<br>
# 6) Mettre l'information 'code' dans les paramètre d'appel de l'API (params=..) puis le supprimer de l'URL. <br>
# 7) Nous allons construire une fonction permettant d'obtenir une information précise sur un pays. <br>
# le comportement attendue est le suivant : la fonction infoPays('FRA','capital') devra retourner 'Paris' <br>
# 7-1) Déclarer la fonction infoPays qui prendra 2 paramètres : 'code', correspondant au code du pays et 'info' correspondant au contenu de la colonne à retourner (capital, monnaie...) <br>
# 7-2) placer dans la fonction l'appel à l'API réalisé à l'étape 6. la variable 'code' de l'api prendra la valeur du paramètre 'code' de la fonction infoPays <br>
# 7-3) Toujours dans la fonction créer ensuite la variable 'info' qui recupera la valeur de la colonne correspondant au paramètre 'info' de la fonction <br>
# 7-4) la fonction doit retourner la variable info en guise de réponse. <br>
# 8) quel est la capitale (capital) du bangladesh (BGD) ? <br>
# 9) quelle est la monnaie (currencies) de la Turquie(TUR) ?

# %%
import requests
import json
from pandas.io.json import json_normalize
import pandas

url_1='https://restcountries.eu/rest/v2/all'
data=requests.get(url_1)
data=json.loads(data.content)
dataSet=json_normalize(data)
dataSet
# Out:
# <ipython-input-8-db05bcb925b0>:9: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataSet=json_normalize(data)
#                   name topLevelDomain alpha2Code alpha3Code callingCodes  \
# 0          Afghanistan          [.af]         AF        AFG         [93]
# 1        Åland Islands          [.ax]         AX        ALA        [358]
# 2              Albania          [.al]         AL        ALB        [355]
# 3              Algeria          [.dz]         DZ        DZA        [213]
# 4       American Samoa          [.as]         AS        ASM       [1684]
# ..                 ...            ...        ...        ...          ...
# 245  Wallis and Futuna          [.wf]         WF        WLF        [681]
# 246     Western Sahara          [.eh]         EH        ESH        [212]
# 247              Yemen          [.ye]         YE        YEM        [967]
# 248             Zambia          [.zm]         ZM        ZMB        [260]
# 249           Zimbabwe          [.zw]         ZW        ZWE        [263]
#
#        capital                                       altSpellings   region  \
# 0        Kabul                                   [AF, Afġānistān]     Asia
# 1    Mariehamn                    [AX, Aaland, Aland, Ahvenanmaa]   Europe
# 2       Tirana                [AL, Shqipëri, Shqipëria, Shqipnia]   Europe
# 3      Algiers                              [DZ, Dzayer, Algérie]   Africa
# 4    Pago Pago  [AS, Amerika Sāmoa, Amelika Sāmoa, Sāmoa Amelika]  Oceania
# ..         ...                                                ...      ...
# 245   Mata-Utu  [WF, Territory of the Wallis and Futuna Island...  Oceania
# 246   El Aaiún                            [EH, Taneẓroft Tutrimt]   Africa
# 247     Sana'a  [YE, Yemeni Republic, al-Jumhūriyyah al-Yamani...     Asia
# 248     Lusaka                           [ZM, Republic of Zambia]   Africa
# 249     Harare                         [ZW, Republic of Zimbabwe]   Africa
#
#            subregion  population  ...     translations.de    translations.es  \
# 0      Southern Asia    27657145  ...         Afghanistan         Afganistán
# 1    Northern Europe       28875  ...               Åland            Alandia
# 2    Southern Europe     2886026  ...            Albanien            Albania
# 3    Northern Africa    40400000  ...            Algerien            Argelia
# 4          Polynesia       57100  ...  Amerikanisch-Samoa    Samoa Americana
# ..               ...         ...  ...                 ...                ...
# 245        Polynesia       11750  ...   Wallis und Futuna    Wallis y Futuna
# 246  Northern Africa      510713  ...          Westsahara  Sahara Occidental
# 247     Western Asia    27478000  ...               Jemen              Yemen
# 248   Eastern Africa    15933883  ...              Sambia             Zambia
# 249   Eastern Africa    14240168  ...            Simbabwe           Zimbabue
#
#        translations.fr  translations.ja     translations.it  translations.br  \
# 0          Afghanistan          アフガニスタン         Afghanistan      Afeganistão
# 1                Åland          オーランド諸島         Isole Aland   Ilhas de Aland
# 2              Albanie            アルバニア             Albania          Albânia
# 3              Algérie           アルジェリア             Algeria          Argélia
# 4    Samoa américaines         アメリカ領サモア     Samoa Americane  Samoa Americana
# ..                 ...              ...                 ...              ...
# 245   Wallis-et-Futuna         ウォリス・フツナ     Wallis e Futuna  Wallis e Futuna
# 246  Sahara Occidental             西サハラ  Sahara Occidentale  Saara Ocidental
# 247              Yémen             イエメン               Yemen            Iêmen
# 248             Zambie             ザンビア              Zambia           Zâmbia
# 249           Zimbabwe            ジンバブエ            Zimbabwe         Zimbabwe
#
#      translations.pt    translations.nl   translations.hr  \
# 0        Afeganistão        Afghanistan        Afganistan
# 1     Ilhas de Aland      Ålandeilanden    Ålandski otoci
# 2            Albânia            Albanië          Albanija
# 3            Argélia           Algerije             Alžir
# 4    Samoa Americana   Amerikaans Samoa    Američka Samoa
# ..               ...                ...               ...
# 245  Wallis e Futuna   Wallis en Futuna  Wallis i Fortuna
# 246  Saara Ocidental  Westelijke Sahara    Zapadna Sahara
# 247            Iémen              Jemen             Jemen
# 248           Zâmbia             Zambia           Zambija
# 249         Zimbabué           Zimbabwe          Zimbabve
#
#                 translations.fa
# 0                     افغانستان
# 1                    جزایر الند
# 2                        آلبانی
# 3                       الجزایر
# 4                 ساموآی آمریکا
# ..                          ...
# 245              والیس و فوتونا
# 246  جمهوری دموکراتیک عربی صحرا
# 247                         یمن
# 248                      زامبیا
# 249                     زیمباوه
#
# [250 rows x 33 columns]

# %%
url_2='https://restcountries.eu/rest/v2/alpha?codes=FRA'
appel_API(url_2)
# Out:
# <ipython-input-1-44cb0c0537ed>:10: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataSet=json_normalize(data)
#      name topLevelDomain alpha2Code alpha3Code callingCodes capital  \
# 0  France          [.fr]         FR        FRA         [33]   Paris
#
#                                   altSpellings  region       subregion  \
# 0  [FR, French Republic, République française]  Europe  Western Europe
#
#    population  ... translations.de translations.es  translations.fr  \
# 0    66710000  ...      Frankreich         Francia           France
#
#    translations.ja translations.it translations.br translations.pt  \
# 0             フランス         Francia          França          França
#
#   translations.nl translations.hr translations.fa
# 0       Frankrijk       Francuska          فرانسه
#
# [1 rows x 33 columns]

# %%
url_3='https://restcountries.eu/rest/v2/alpha'
parametres={'codes':'FRA'}
data=requests.get(url_3, params=parametres)
data=json.loads(data.content)
dataSet=json_normalize(data)
dataSet
# Out:
# <ipython-input-3-58f557ef0855>:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataSet=json_normalize(data)
#      name topLevelDomain alpha2Code alpha3Code callingCodes capital  \
# 0  France          [.fr]         FR        FRA         [33]   Paris
#
#                                   altSpellings  region       subregion  \
# 0  [FR, French Republic, République française]  Europe  Western Europe
#
#    population  ... translations.de translations.es  translations.fr  \
# 0    66710000  ...      Frankreich         Francia           France
#
#    translations.ja translations.it translations.br translations.pt  \
# 0             フランス         Francia          França          França
#
#   translations.nl translations.hr translations.fa
# 0       Frankrijk       Francuska          فرانسه
#
# [1 rows x 33 columns]

# %%
url_3='https://restcountries.eu/rest/v2/alpha'

def infoPays(code, info):
    parametres={'codes':code
               }
    data=requests.get(url_3, params=parametres)
    data=json.loads(data.content)
    dataSet=json_normalize(data)
    info= dataSet[info][0]
    return info

# %%
infoPays('FRA','capital')
# Out:
# <ipython-input-13-31cae2b892a3>:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataSet=json_normalize(data)
# 'Paris'

# %%
infoPays('AFG','capital')
# Out:
# <ipython-input-13-31cae2b892a3>:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataSet=json_normalize(data)
# 'Kabul'

# %%
infoPays('FRA','currencies')
# Out:
# <ipython-input-13-31cae2b892a3>:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataSet=json_normalize(data)
# [{'code': 'EUR', 'name': 'Euro', 'symbol': '€'}]
