# %% [markdown]
# <h1>Découverte du dataset</h1>

# %%
import pandas as pd
chemin=r"C:\Users\dell\Documents\Perso\cours_python\Datafiniti_Womens_Shoes.csv"
shoes=pd.read_csv(chemin, encoding='utf-8', sep=',')
shoes.head()
# Out:
#                      id             dateAdded           dateUpdated asins  \
# 0  AVpfEf_hLJeJML431ueH  2015-05-04T12:13:08Z  2018-01-29T04:38:43Z   NaN
# 1  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 2  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 3  AVpjXyCc1cnluZ0-V-Gj  2017-01-27T01:25:56Z  2018-01-04T11:52:35Z   NaN
# 4  AVphGKLPilAPnD_x1Nrm  2017-01-27T01:25:56Z  2018-01-18T03:55:18Z   NaN
#
#          brand                                         categories  \
# 0  Naturalizer  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 1     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 2     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 3     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 4     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
#
#   primaryCategories                          colors                 dimension  \
# ...

# %%
pd.set_option("display.max_row",35)

# %%
shoes.head()
# Out:
#                      id             dateAdded           dateUpdated asins  \
# 0  AVpfEf_hLJeJML431ueH  2015-05-04T12:13:08Z  2018-01-29T04:38:43Z   NaN
# 1  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 2  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 3  AVpjXyCc1cnluZ0-V-Gj  2017-01-27T01:25:56Z  2018-01-04T11:52:35Z   NaN
# 4  AVphGKLPilAPnD_x1Nrm  2017-01-27T01:25:56Z  2018-01-18T03:55:18Z   NaN
#
#          brand                                         categories  \
# 0  Naturalizer  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 1     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 2     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 3     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 4     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
#
#   primaryCategories                          colors                 dimension  \
# ...

# %%
filtre=["id","brand","dateUpdated","colors","prices.amountMax","prices.amountMin","prices.merchant"]
shoesLight=shoes[filtre]

# %%
shoesLight.head()
# Out:
#                      id        brand           dateUpdated  \
# 0  AVpfEf_hLJeJML431ueH  Naturalizer  2018-01-29T04:38:43Z
# 1  AVpi74XfLJeJML43qZAc     MUK LUKS  2018-01-03T05:21:54Z
# 2  AVpi74XfLJeJML43qZAc     MUK LUKS  2018-01-03T05:21:54Z
# 3  AVpjXyCc1cnluZ0-V-Gj     MUK LUKS  2018-01-04T11:52:35Z
# 4  AVphGKLPilAPnD_x1Nrm     MUK LUKS  2018-01-18T03:55:18Z
#
#                            colors  prices.amountMax  prices.amountMin  \
# 0  Silver,Cream Watercolor Floral             55.99             55.99
# 1                            Grey             47.00             35.25
# 2                            Grey             35.25             35.25
# 3                           Black             24.75             24.75
# 4                            Grey             33.00             30.39
#
#     prices.merchant
# 0     Overstock.com
# 1       Walmart.com
# 2  Slippers Dot Com
# 3  Slippers Dot Com
# 4       Walmart.com

# %% [markdown]
# <h1>Data cleaning</h1>

# %%
    shoesLight.dtypes
# Out:
# id                   object
# brand                object
# dateUpdated          object
# colors               object
# prices.amountMax    float64
# prices.amountMin    float64
# prices.merchant      object
# dtype: object

# %% [markdown]
# <p> dateUpdated doit être de type datetime64: correction avec dt</p>
# <p> colors doit etre converti en liste</p>

# %%
shoesLight.isnull()
# Out:
#          id  brand  dateUpdated  colors  prices.amountMax  prices.amountMin  \
# 0     False  False        False   False             False             False
# 1     False  False        False   False             False             False
# 2     False  False        False   False             False             False
# 3     False  False        False   False             False             False
# 4     False  False        False   False             False             False
# ...     ...    ...          ...     ...               ...               ...
# 9995  False  False        False   False             False             False
# 9996  False  False        False   False             False             False
# 9997  False  False        False   False             False             False
# 9998  False  False        False   False             False             False
# 9999  False  False        False   False             False             False
#
#       prices.merchant
# 0               False
# ...

# %%
shoesLight.isnull().sum()
# Out:
# id                     0
# brand                  0
# dateUpdated            0
# colors              7369
# prices.amountMax       0
# prices.amountMin       0
# prices.merchant     9565
# dtype: int64

# %%
shoesLight.isnull().sum()/len(shoesLight)
# Out:
# id                  0.0000
# brand               0.0000
# dateUpdated         0.0000
# colors              0.7369
# prices.amountMax    0.0000
# prices.amountMin    0.0000
# prices.merchant     0.9565
# dtype: float64

# %%
shoesLight.dropna(axis=0, inplace=True)
# Out:
# <ipython-input-10-de9131b62e1e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shoesLight.dropna(axis=0, inplace=True)

# %%
shoesLight.dtypes
# Out:
# id                   object
# brand                object
# dateUpdated          object
# colors               object
# prices.amountMax    float64
# prices.amountMin    float64
# prices.merchant      object
# dtype: object

# %%
shoesLight['dateUpdated'] = pd.to_datetime(shoesLight['dateUpdated'])
# Out:
# <ipython-input-12-1fe463821fb4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shoesLight['dateUpdated'] = pd.to_datetime(shoesLight['dateUpdated'])

# %%
shoesLight.dtypes
# Out:
# id                               object
# brand                            object
# dateUpdated         datetime64[ns, UTC]
# colors                           object
# prices.amountMax                float64
# prices.amountMin                float64
# prices.merchant                  object
# dtype: object

# %%
shoesLight.isnull().sum()
# Out:
# id                  0
# brand               0
# dateUpdated         0
# colors              0
# prices.amountMax    0
# prices.amountMin    0
# prices.merchant     0
# dtype: int64

# %% [markdown]
# <h1>Features Modeling</h1>

# %%
amountAverage=(shoesLight["prices.amountMax"]+shoesLight["prices.amountMin"])/2
shoesLight["prices.amountAverage"]=amountAverage
# Out:
# <ipython-input-15-4bf0f1c61d9b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shoesLight["prices.amountAverage"]=amountAverage

# %%
shoesLight.head()
# Out:
#                      id        brand               dateUpdated  \
# 0  AVpfEf_hLJeJML431ueH  Naturalizer 2018-01-29 04:38:43+00:00
# 1  AVpi74XfLJeJML43qZAc     MUK LUKS 2018-01-03 05:21:54+00:00
# 2  AVpi74XfLJeJML43qZAc     MUK LUKS 2018-01-03 05:21:54+00:00
# 3  AVpjXyCc1cnluZ0-V-Gj     MUK LUKS 2018-01-04 11:52:35+00:00
# 4  AVphGKLPilAPnD_x1Nrm     MUK LUKS 2018-01-18 03:55:18+00:00
#
#                            colors  prices.amountMax  prices.amountMin  \
# 0  Silver,Cream Watercolor Floral             55.99             55.99
# 1                            Grey             47.00             35.25
# 2                            Grey             35.25             35.25
# 3                           Black             24.75             24.75
# 4                            Grey             33.00             30.39
#
#     prices.merchant  prices.amountAverage
# 0     Overstock.com                55.990
# 1       Walmart.com                41.125
# ...

# %%
days={0:"sunday",
      1:"monday",
      2:"tuesday",
      3:"wednesday",
      4:"thursday",
      5:"friday",
      6:"saturday"
     }

# %%
shoesLight["dayOfweekUpdated"]=shoesLight["dateUpdated"].dt.weekday
# Out:
# <ipython-input-29-8699d5443e33>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shoesLight["dayOfweekUpdated"]=shoesLight["dateUpdated"].dt.weekday

# %%
shoesLight.head()
# Out:
#                      id        brand               dateUpdated  \
# 0  AVpfEf_hLJeJML431ueH  Naturalizer 2018-01-29 04:38:43+00:00
# 1  AVpi74XfLJeJML43qZAc     MUK LUKS 2018-01-03 05:21:54+00:00
# 2  AVpi74XfLJeJML43qZAc     MUK LUKS 2018-01-03 05:21:54+00:00
# 3  AVpjXyCc1cnluZ0-V-Gj     MUK LUKS 2018-01-04 11:52:35+00:00
# 4  AVphGKLPilAPnD_x1Nrm     MUK LUKS 2018-01-18 03:55:18+00:00
#
#                            colors  prices.amountMax  prices.amountMin  \
# 0  Silver,Cream Watercolor Floral             55.99             55.99
# 1                            Grey             47.00             35.25
# 2                            Grey             35.25             35.25
# 3                           Black             24.75             24.75
# 4                            Grey             33.00             30.39
#
#     prices.merchant  prices.amountAverage  dayOfweekUpdated
# 0     Overstock.com                55.990                 0
# ...

# %%
shoesLight["dateUpdated"].dt.weekday.value_counts()
# Out:
# 1    121
# 5    112
# 4     85
# 0     39
# 3     34
# 2     24
# 6     20
# Name: dateUpdated, dtype: int64

# %% [markdown]
# <h1>Data analysis </h1>

# %%
shoesLight["prices.amountAverage"].describe()
# Out:
# count    435.000000
# mean      95.785460
# std       39.405099
# min        5.375000
# 25%       67.950000
# 50%       99.950000
# 75%      119.960000
# max      179.950000
# Name: prices.amountAverage, dtype: float64

# %%
luxe=shoesLight[['prices.amountAverage','brand']].groupby('brand').mean().sort_values(['prices.amountAverage'],ascending=False).head(10)

# %%
luxe
# Out:
#               prices.amountAverage
# brand
# Free People             178.000000
# On Footwear             159.990000
# MLB                     151.240000
# Arc'teryx               150.166667
# La Sportiva             149.437500
# Frye                    149.322500
# Lowa                    146.392857
# SoftWalk                145.950000
# Scarpa                  145.337500
# Hoka One One            144.235714

# %%
lowcost=shoesLight[['prices.amountAverage','brand']].groupby('brand').mean().sort_values(['prices.amountAverage'],ascending=True).head(10)

# %%
lowcost
# Out:
#                  prices.amountAverage
# brand
# Unbranded                    6.803333
# Soft Ones                   10.950000
# Faded Glory                 13.381250
# Victoria K.                 15.880000
# Genuine Dickies             16.925000
# Earth Spirit                18.100000
# Danskin Now                 19.740000
# Riverberry                  24.990000
# Mo Mo                       25.046667
# Carrini                     27.700000
