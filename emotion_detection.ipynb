# %%
import cv2 as cv
# Code optionnel pour éliminer les warnings

from warnings import filterwarnings
filterwarnings('ignore')

# %%
from deepface import DeepFace

# %%
chemin=r"C:\Users\dell\Pictures\photo_maodo.jpg" #"C:\Users\dell\Documents\Perso\happy boy.png"
img=cv.imread(chemin)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))

# %%
predictions=DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.44it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 16.158169507980347,
#   'disgust': 1.426345153099362e-07,
#   'fear': 0.10726634645834565,
#   'happy': 2.1138044203894424e-06,
#   'sad': 7.318546622991562,
#   'surprise': 3.2259390714273195e-07,
#   'neutral': 76.416015625},
#  'dominant_emotion': 'neutral',
#  'age': 29,
#  'gender': 'Man',
#  'race': {'asian': 1.3342769662361843e-16,
#   'indian': 3.867999247042812e-13,
#   'black': 100.0,
#   'white': 6.392345511879282e-23,
#   'middle eastern': 2.851416628011869e-23,
#   'latino hispanic': 8.55096552019651e-16},
#  'dominant_race': 'black'}

# %%
predictions['dominant_emotion']
# Out:
# 'neutral'

# %%
face_cascade=cv.CascadeClassifier(r"C:\Users\dell\Documents\Perso\haar-cascade-files-master\haarcascade_frontalface_default.xml")

# %%
gray=cv.cvtColor(img, cv.COLOR_BGR2GRAY)
face_rect=face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=4)
for (x,y,w,h) in face_rect:
    cv.rectangle(img, (x,y),(x+w, y+h),(0,255,0), 2)
    cv.putText(img, str(predictions['dominant_emotion']), (20,20), cv.FONT_HERSHEY_COMPLEX, 1.0, (0,250,0), thickness=2)

# %%
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
