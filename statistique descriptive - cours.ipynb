# %% [markdown]
# Definition wikipedia : L'objectif de la statistique descriptive est de décrire, c'est-à-dire de résumer ou représenter, par des statistiques, les données disponibles quand elles sont nombreuses.

# %%
import pandas as pd
chemin=r"C:\Users\dell\Documents\Perso\cours_python\15_statistique_descriptive\DigiDB_digimonlist.csv"
data = pd.read_csv(chemin)
data.head(5)
# Out:
#    Number  Digimon Stage  Type Attribute  Memory  Equip Slots  Lv 50 HP  \
# 0       1  Kuramon  Baby  Free   Neutral       2            0       590
# 1       2  Pabumon  Baby  Free   Neutral       2            0       950
# 2       3  Punimon  Baby  Free   Neutral       2            0       870
# 3       4  Botamon  Baby  Free   Neutral       2            0       690
# 4       5  Poyomon  Baby  Free   Neutral       2            0       540
#
#    Lv50 SP  Lv50 Atk  Lv50 Def  Lv50 Int  Lv50 Spd
# 0       77        79        69        68        95
# 1       62        76        76        69        68
# 2       50        97        87        50        75
# 3       68        77        95        76        61
# 4       98        54        59        95        86

# %% [markdown]
# <b> Les types de variables </b>
#
# <b>Les variables catégorielles (qualitatives) </b>
# <p> Il n'y a pas de notion d'échelle, c'est un attribut d'un critère<br>
# Exemples : [homme,Femme], [première classe, deuxième classe, troisième classe], [Vrai,Faux]<p>

# %%
from matplotlib import pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
sns.countplot(x="Type", data=data)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
sns.countplot(x="Attribute", data=data)
# Out:
# <AxesSubplot:xlabel='Attribute', ylabel='count'>

# %% [markdown]
# <b>Les variables quantitatives </b>
# <p> A l'inverse, ces variables permettent de mesurer des quantités <br>
# Il en existe 2 types : Variables quantitatives discrètes et continues </p>
#
# <b>Les variables quantitatives discrètes </b>
# <p> C'est une variable avec un nombre fini de valeurs <br>
# Exemples : nombre d'items, nombre de personnes <p>

# %%
#les variables quantitatives discrètes
sns.distplot(list(data['Memory']))
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(list(data['Lv 50 HP']))
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# <b>Les variables quantitatives continues </b>
# <p> C'est une variable avec une infinité de valeurs <br>
# Exemples : poids, durée <p>
# <p> pas de variable quantitative continue dans le data set !

# %% [markdown]
# <b> Description d'une variable continue </b> <br>
# <b> La moyenne </b>
# <p> Somme des valeurs de la variable divisée par le nombre d'individus </p>
#
# ![moyenne.PNG](attachment:moyenne.PNG)

# %%
mean = data['Lv 50 HP'].mean()
print(mean)
sns.distplot(list(data['Lv 50 HP']))
plt.axvline(mean, color='r')
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 1210.8835341365461

# %% [markdown]
# <b> La Médiane </b>
# <p>  valeur centrale qui partage l'échantillon en 2 groupes de même effectif : 50 % au-dessus et 50 % en dessous <p>

# %%
median = data['Lv 50 HP'].median()
print(median)
sns.distplot(list(data['Lv 50 HP']))
plt.axvline(mean, color='r')
plt.axvline(median, color='g')
# Out:
# 1180.0
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# <b> Le mode </b>
# <p> C'est la valeur la plus fréquente </p>

# %%
mode = data['Lv 50 HP'].mode()
print(mode)
sns.distplot(list(data['Lv 50 HP']))
plt.axvline(mean, color='r')
plt.axvline(median, color='g')
plt.axvline(float(mode), color='y')
# Out:
# 0    1480
# dtype: int64
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
mode = data['Lv 50 HP'].mode()
print(mode)
nbValDif = len(data['Lv 50 HP'].unique())
sns.distplot(list(data['Lv 50 HP']), bins=nbValDif)
plt.axvline(float(mode), color='y')
# Out:
# 0    1480
# dtype: int64
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
mode = data['Type'].mode()
print(mode)
sns.countplot(x="Type", data=data)
# Out:
# 0    Virus
# dtype: object
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %% [markdown]
# <b> la variance </b>
# <p>moyenne arithmétique des carrés des écarts à la moyenne arithmétique observée</p>
#
#
# ![image.png](attachment:image.png)

# %%
variance = data['Lv 50 HP'].var()
variance
# Out:
# 106342.76460681428

# %% [markdown]
# <b> l'écart type </b>
# <p>c'est la racine carrée de la variance</p>
#
# ![image.png](attachment:image.png)

# %%
ecartType = data['Lv 50 HP'].std()
ecartType
# Out:
# 326.1023836263916

# %%
variance**(1/2)
# Out:
# 326.1023836263916

# %% [markdown]
# <b> Les quantiles </b>
# <p>Avec son utilisation la plus connue : les quartiles<br>
# Dans la même logique que la médiane les quartile vont couper la population en 4 parties contenant le même nombre d'observation</p>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ax = sns.boxplot(x="Type", y="Lv 50 HP", data=data)
plt.show()

# %% [markdown]
# <b> La loi normale <b><br>
# <b> Quelques exemples <b>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.distplot(list(data['Lv 50 HP']))
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# Dans une expérience aléatoire, plus on augmente le nombre d'obeservations et plus la répartition va se lisser et se rapprocher de la fonction de gauss
# ![image.png](attachment:image.png)

# %% [markdown]
# <b><p>Distribution de la fonction de Gauss :</p> <b>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b> Calculer le coéficient d'assymétrie (skewness) de sa distribution </b>
#
# Fait référence à l'asymétrie des données. Lorsque les données sont concentrées sur le côté droit de l'histogramme, par exemple, nous disons qu'elles ont un skew négatif. Lorsque les données sont concentrées à gauche, on dit qu'elles ont un skew positif.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.distplot(list(data['Lv 50 HP']))
data['Lv 50 HP'].skew()
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 0.1374660716485841

# %% [markdown]
# <b> Calculer le coéficient d'applatissement d'une distribution : Kurtosis </b>
#
# <p>Plus la valeur d'aplatissement est élevée, plus le pic est élevé. Plus la valeur de kustose est faible, plus la valeur est étalée.</p>
#
# ![image.png](attachment:image.png)

# %%
sns.distplot(list(data['Lv 50 HP']))
data['Lv 50 HP'].kurtosis()
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# -0.5447522937424649

# %% [markdown]
# <b> Notion de correlation entre des variables et calcul du coefficient de correlation </b>

# %% [markdown]
# La correlation indique s'il y a une liaison entre 2 variables, c'est à dire determiner si les variables sont indépendantes ou non.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b> Calcul du coeficient de corrélation (pour 2 variables) </b> <br>
#     <p> étape 1 : calculer la covariance </p>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Etape 2 : calculer le coéficient de corrélation (valeur comprise entre -1 et 1)
#
# Plus le CC est eloigné de 0, plus la corrélation est forte, plus il est proche de 0 plus la corrélation est faible
#
# ![image.png](attachment:image.png)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data,figsize=(25,25))
# Out:
# array([[<AxesSubplot:xlabel='Number', ylabel='Number'>,
#         <AxesSubplot:xlabel='Memory', ylabel='Number'>,
#         <AxesSubplot:xlabel='Equip Slots', ylabel='Number'>,
#         <AxesSubplot:xlabel='Lv 50 HP', ylabel='Number'>,
#         <AxesSubplot:xlabel='Lv50 SP', ylabel='Number'>,
#         <AxesSubplot:xlabel='Lv50 Atk', ylabel='Number'>,
#         <AxesSubplot:xlabel='Lv50 Def', ylabel='Number'>,
#         <AxesSubplot:xlabel='Lv50 Int', ylabel='Number'>,
#         <AxesSubplot:xlabel='Lv50 Spd', ylabel='Number'>],
#        [<AxesSubplot:xlabel='Number', ylabel='Memory'>,
#         <AxesSubplot:xlabel='Memory', ylabel='Memory'>,
#         <AxesSubplot:xlabel='Equip Slots', ylabel='Memory'>,
#         <AxesSubplot:xlabel='Lv 50 HP', ylabel='Memory'>,
#         <AxesSubplot:xlabel='Lv50 SP', ylabel='Memory'>,
#         <AxesSubplot:xlabel='Lv50 Atk', ylabel='Memory'>,
#         <AxesSubplot:xlabel='Lv50 Def', ylabel='Memory'>,
# ...

# %%
sns.jointplot("Lv 50 HP", "Lv50 SP", data=data)
data[["Lv 50 HP", "Lv50 SP"]].corr()
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
#           Lv 50 HP   Lv50 SP
# Lv 50 HP  1.000000  0.070957
# Lv50 SP   0.070957  1.000000

# %%
sns.jointplot("Lv50 Int", "Lv50 SP", data=data)
data[["Lv50 Int", "Lv50 SP"]].corr()
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
#           Lv50 Int   Lv50 SP
# Lv50 Int  1.000000  0.895652
# Lv50 SP   0.895652  1.000000

# %%
data.corr()
# Out:
#                Number    Memory  Equip Slots  Lv 50 HP   Lv50 SP  Lv50 Atk  \
# Number       1.000000  0.923339     0.571901  0.626166  0.608113  0.552471
# Memory       0.923339  1.000000     0.355176  0.639569  0.623400  0.608372
# Equip Slots  0.571901  0.355176     1.000000  0.392137  0.278687  0.211450
# Lv 50 HP     0.626166  0.639569     0.392137  1.000000  0.070957  0.605708
# Lv50 SP      0.608113  0.623400     0.278687  0.070957  1.000000 -0.148365
# Lv50 Atk     0.552471  0.608372     0.211450  0.605708 -0.148365  1.000000
# Lv50 Def     0.620177  0.611728     0.466534  0.561376  0.169960  0.426901
# Lv50 Int     0.560146  0.583956     0.237616  0.055314  0.895652 -0.186125
# Lv50 Spd     0.762861  0.797777     0.286558  0.317051  0.603240  0.522005
#
#              Lv50 Def  Lv50 Int  Lv50 Spd
# Number       0.620177  0.560146  0.762861
# Memory       0.611728  0.583956  0.797777
# Equip Slots  0.466534  0.237616  0.286558
# Lv 50 HP     0.561376  0.055314  0.317051
# ...

# %%
import seaborn as sns
sns.heatmap(data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data)
