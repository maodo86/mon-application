# %% [markdown]
# <b> Comprendre le langage SQL </b><br>
# SQL  est un langage informatique normalisé servant à exploiter des bases de données relationnelles. La partie langage de manipulation des données de SQL permet de rechercher, d'ajouter, de modifier ou de supprimer des données dans les bases de données relationnelles.

# %% [markdown]
# ![sql.jpg](attachment:sql.jpg)

# %% [markdown]
# <b> connexion en Python à une base de données </b>

# %%
import sqlite3
path ='C:\\Users\\dell\\Documents\\Perso\\cours_python\\14_SQL/database.sqlite'
conn = sqlite3.connect(path)
conn

# %%
#importer une table complète
import pandas as pd

teams = pd.read_sql("""SELECT *
                        FROM Team;""", conn)
teams
# Out:
#         id  team_api_id  team_fifa_api_id      team_long_name team_short_name
# 0        1         9987             673.0            KRC Genk             GEN
# 1        2         9993             675.0        Beerschot AC             BAC
# 2        3        10000           15005.0    SV Zulte-Waregem             ZUL
# 3        4         9994            2007.0    Sporting Lokeren             LOK
# 4        5         9984            1750.0   KSV Cercle Brugge             CEB
# ..     ...          ...               ...                 ...             ...
# 294  49479        10190             898.0       FC St. Gallen             GAL
# 295  49837        10191            1715.0             FC Thun             THU
# 296  50201         9777             324.0         Servette FC             SER
# 297  50204         7730            1862.0  FC Lausanne-Sports             LAU
# 298  51606         7896               NaN              Lugano             LUG
#
# [299 rows x 5 columns]

# %%
#Selectionner certaines colonnes d'une table
teams = pd.read_sql("""SELECT team_long_name,team_short_name
                        FROM Team;""", conn)
teams
# Out:
#          team_long_name team_short_name
# 0              KRC Genk             GEN
# 1          Beerschot AC             BAC
# 2      SV Zulte-Waregem             ZUL
# 3      Sporting Lokeren             LOK
# 4     KSV Cercle Brugge             CEB
# ..                  ...             ...
# 294       FC St. Gallen             GAL
# 295             FC Thun             THU
# 296         Servette FC             SER
# 297  FC Lausanne-Sports             LAU
# 298              Lugano             LUG
#
# [299 rows x 2 columns]

# %%
#Acceder à une autre table
players = pd.read_sql("""SELECT *
                        FROM Player_Attributes;""", conn)
players
# Out:
#             id  player_fifa_api_id  player_api_id                 date  \
# 0            1              218353         505942  2016-02-18 00:00:00
# 1            2              218353         505942  2015-11-19 00:00:00
# 2            3              218353         505942  2015-09-21 00:00:00
# 3            4              218353         505942  2015-03-20 00:00:00
# 4            5              218353         505942  2007-02-22 00:00:00
# ...        ...                 ...            ...                  ...
# 183973  183974              102359          39902  2009-08-30 00:00:00
# 183974  183975              102359          39902  2009-02-22 00:00:00
# 183975  183976              102359          39902  2008-08-30 00:00:00
# 183976  183977              102359          39902  2007-08-30 00:00:00
# 183977  183978              102359          39902  2007-02-22 00:00:00
#
#         overall_rating  potential preferred_foot attacking_work_rate  \
# 0                 67.0       71.0          right              medium
# 1                 67.0       71.0          right              medium
# 2                 62.0       66.0          right              medium
# 3                 61.0       65.0          right              medium
# 4                 61.0       65.0          right              medium
# ...                ...        ...            ...                 ...
# 183973            83.0       85.0          right              medium
# 183974            78.0       80.0          right              medium
# 183975            77.0       80.0          right              medium
# 183976            78.0       81.0          right              medium
# 183977            80.0       81.0          right              medium
#
#        defensive_work_rate  crossing  ...  vision  penalties  marking  \
# 0                   medium      49.0  ...    54.0       48.0     65.0
# 1                   medium      49.0  ...    54.0       48.0     65.0
# 2                   medium      49.0  ...    54.0       48.0     65.0
# 3                   medium      48.0  ...    53.0       47.0     62.0
# 4                   medium      48.0  ...    53.0       47.0     62.0
# ...                    ...       ...  ...     ...        ...      ...
# 183973                 low      84.0  ...    88.0       83.0     22.0
# 183974                 low      74.0  ...    88.0       70.0     32.0
# 183975                 low      74.0  ...    88.0       70.0     32.0
# 183976                 low      74.0  ...    88.0       53.0     28.0
# 183977                 low      74.0  ...    88.0       53.0     38.0
#
#         standing_tackle  sliding_tackle  gk_diving  gk_handling  gk_kicking  \
# 0                  69.0            69.0        6.0         11.0        10.0
# 1                  69.0            69.0        6.0         11.0        10.0
# 2                  66.0            69.0        6.0         11.0        10.0
# 3                  63.0            66.0        5.0         10.0         9.0
# 4                  63.0            66.0        5.0         10.0         9.0
# ...                 ...             ...        ...          ...         ...
# 183973             31.0            30.0        9.0         20.0        84.0
# 183974             31.0            30.0        9.0         20.0        73.0
# 183975             31.0            30.0        9.0         20.0        73.0
# 183976             32.0            30.0        9.0         20.0        73.0
# 183977             32.0            30.0        9.0          9.0        78.0
#
#         gk_positioning  gk_reflexes
# 0                  8.0          8.0
# 1                  8.0          8.0
# 2                  8.0          8.0
# 3                  7.0          7.0
# 4                  7.0          7.0
# ...                ...          ...
# 183973            20.0         20.0
# 183974            20.0         20.0
# 183975            20.0         20.0
# 183976            20.0         20.0
# 183977             7.0         15.0
#
# [183978 rows x 42 columns]

# %%
#Afficher toutes les tables d'une base de données
tables = pd.read_sql("""SELECT *
                        FROM sqlite_master
                        WHERE type='table';""", conn)
tables
# Out:
#     type               name           tbl_name  rootpage  \
# 0  table    sqlite_sequence    sqlite_sequence         4
# 1  table  Player_Attributes  Player_Attributes        11
# 2  table             Player             Player        14
# 3  table              Match              Match        18
# 4  table             League             League        24
# 5  table            Country            Country        26
# 6  table               Team               Team        29
# 7  table    Team_Attributes    Team_Attributes         2
#
#                                                  sql
# 0             CREATE TABLE sqlite_sequence(name,seq)
# 1  CREATE TABLE "Player_Attributes" (\n\t`id`\tIN...
# 2  CREATE TABLE `Player` (\n\t`id`\tINTEGER PRIMA...
# 3  CREATE TABLE `Match` (\n\t`id`\tINTEGER PRIMAR...
# 4  CREATE TABLE `League` (\n\t`id`\tINTEGER PRIMA...
# 5  CREATE TABLE `Country` (\n\t`id`\tINTEGER PRIM...
# 6  CREATE TABLE "Team" (\n\t`id`\tINTEGER PRIMARY...
# 7  CREATE TABLE `Team_Attributes` (\n\t`id`\tINTE...

# %%
#Appliquer un filtre
players = pd.read_sql("""SELECT id,overall_rating
                        FROM Player_Attributes
                        WHERE overall_rating > 90;""", conn)
players
# Out:
#         id  overall_rating
# 0     6532              91
# 1     6533              91
# 2    12789              91
# 3    12790              91
# 4    33331              93
# 5    33332              93
# 6    33333              93
# 7    33334              92
# 8    33335              92
# 9    33336              92
# 10   33337              92
# 11   33338              92
# 12   33339              92
# 13   33340              92
# 14   33341              92
# 15   33342              92
# 16   33343              92
# 17   33344              92
# 18   33345              92
# 19   33346              92
# 20   33347              92
# 21   33353              91
# 22   33354              91
# 23   53198              91
# 24   63875              91
# 25   63876              93
# 26   66758              92
# 27   72609              91
# 28   72610              91
# 29   84856              91
# 30  102483              94
# 31  102484              94
# 32  102485              94
# 33  102486              93
# 34  102487              93
# 35  102488              93
# 36  102489              93
# 37  102490              93
# 38  102491              93
# 39  102492              94
# 40  102493              94
# 41  102494              94
# 42  102495              94
# 43  102496              94
# 44  102497              94
# 45  102498              94
# 46  102499              94
# 47  102500              94
# 48  153453              91
# 49  153454              91
# 50  170037              91
# 51  170038              91
# 52  178976              93
# 53  180723              91
# 54  180724              92

# %%
#Mettre une limite sur le nombre de résultats
players = pd.read_sql("""SELECT id,overall_rating
                        FROM Player_Attributes
                        WHERE overall_rating > 90
                        LIMIT 5;""", conn)
players
# Out:
#       id  overall_rating
# 0   6532              91
# 1   6533              91
# 2  12789              91
# 3  12790              91
# 4  33331              93

# %%
#conditions multiples
players = pd.read_sql("""SELECT id,overall_rating,preferred_foot
                        FROM Player_Attributes
                        WHERE overall_rating > 80 and preferred_foot=='left'
                        LIMIT 5;""", conn)
players
# Out:
#      id  overall_rating preferred_foot
# 0  1744              82           left
# 1  1745              81           left
# 2  1746              81           left
# 3  3245              83           left
# 4  3248              86           left

# %%
#conditions multiples sans avoir besoin de selectionner les colonnes
players = pd.read_sql("""SELECT id
                        FROM Player_Attributes
                        WHERE overall_rating > 80 and preferred_foot=='left'
                        LIMIT 5;""", conn)
players
# Out:
#      id
# 0  1744
# 1  1745
# 2  1746
# 3  3245
# 4  3248

# %%
#Gérer les priorités dans les conditions
players = pd.read_sql("""SELECT id,overall_rating,preferred_foot,attacking_work_rate
                        FROM Player_Attributes
                        WHERE (preferred_foot=='right') and (overall_rating > 80 or attacking_work_rate=='medium')
                        LIMIT 5;""", conn)
players
# Out:
#    id  overall_rating preferred_foot attacking_work_rate
# 0   1              67          right              medium
# 1   2              67          right              medium
# 2   3              62          right              medium
# 3   4              61          right              medium
# 4   5              61          right              medium

# %%
#Filtre sur une série de valeurs
countries = pd.read_sql("""SELECT *
                        FROM Country;""", conn)
countries
# Out:
#        id         name
# 0       1      Belgium
# 1    1729      England
# 2    4769       France
# 3    7809      Germany
# 4   10257        Italy
# 5   13274  Netherlands
# 6   15722       Poland
# 7   17642     Portugal
# 8   19694     Scotland
# 9   21518        Spain
# 10  24558  Switzerland

# %%
countries = pd.read_sql("""SELECT *
                        FROM Country
                        WHERE (name IN ('Belgium','France','Portugal')) ;""", conn)
countries
# Out:
#       id      name
# 0      1   Belgium
# 1   4769    France
# 2  17642  Portugal

# %%
#Changer le tri 
players = pd.read_sql("""SELECT id,overall_rating,preferred_foot,attacking_work_rate
                        FROM Player_Attributes
                        ORDER BY overall_rating ASC
                        LIMIT 5;""", conn)
players
# Out:
#      id overall_rating preferred_foot attacking_work_rate
# 0   484           None           None                None
# 1   984           None           None                None
# 2  1753           None           None                None
# 3  2090           None           None                None
# 4  2483           None           None                None

# %%
#Ignorer les valeurs nulles
players = pd.read_sql("""SELECT id,overall_rating,preferred_foot,attacking_work_rate
                        FROM Player_Attributes
                        WHERE overall_rating IS NOT NULL
                        ORDER BY overall_rating ASC
                        LIMIT 5;""", conn)
players
# Out:
#        id  overall_rating preferred_foot attacking_work_rate
# 0   57834              33          right              medium
# 1   57835              33          right              medium
# 2   76552              35          right              medium
# 3   76553              35          right              medium
# 4  131895              35           left                high

# %%
#Changer le tri 
players = pd.read_sql("""SELECT id,overall_rating,preferred_foot,attacking_work_rate
                        FROM Player_Attributes
                        ORDER BY overall_rating DESC
                        LIMIT 5;""", conn)
players
# Out:
#        id  overall_rating preferred_foot attacking_work_rate
# 0  102483              94           left              medium
# 1  102484              94           left              medium
# 2  102485              94           left              medium
# 3  102492              94           left              medium
# 4  102493              94           left                high

# %%
#Faire un double tri
players = pd.read_sql("""SELECT id,overall_rating,preferred_foot,attacking_work_rate,standing_tackle
                        FROM Player_Attributes
                        ORDER BY overall_rating DESC,standing_tackle ASC
                        LIMIT 10;""", conn)
players
# Out:
#        id  overall_rating preferred_foot attacking_work_rate  standing_tackle
# 0  102492              94           left              medium               21
# 1  102493              94           left                high               21
# 2  102494              94           left                high               21
# 3  102495              94           left                high               21
# 4  102496              94           left                high               21
# 5  102497              94           left                high               21
# 6  102498              94           left                high               21
# 7  102499              94           left                high               21
# 8  102500              94           left                high               21
# 9  102483              94           left              medium               23

# %%
match = pd.read_sql("""SELECT *
                        FROM match;""", conn)
list(match.columns)
# Out:
# ['id',
#  'country_id',
#  'league_id',
#  'season',
#  'stage',
#  'date',
#  'match_api_id',
#  'home_team_api_id',
#  'away_team_api_id',
#  'home_team_goal',
#  'away_team_goal',
#  'home_player_X1',
#  'home_player_X2',
#  'home_player_X3',
#  'home_player_X4',
#  'home_player_X5',
#  'home_player_X6',
#  'home_player_X7',
#  'home_player_X8',
#  'home_player_X9',
#  'home_player_X10',
#  'home_player_X11',
#  'away_player_X1',
#  'away_player_X2',
#  'away_player_X3',
#  'away_player_X4',
#  'away_player_X5',
#  'away_player_X6',
#  'away_player_X7',
#  'away_player_X8',
#  'away_player_X9',
#  'away_player_X10',
#  'away_player_X11',
#  'home_player_Y1',
#  'home_player_Y2',
#  'home_player_Y3',
#  'home_player_Y4',
#  'home_player_Y5',
#  'home_player_Y6',
#  'home_player_Y7',
#  'home_player_Y8',
#  'home_player_Y9',
#  'home_player_Y10',
#  'home_player_Y11',
#  'away_player_Y1',
#  'away_player_Y2',
#  'away_player_Y3',
#  'away_player_Y4',
#  'away_player_Y5',
#  'away_player_Y6',
#  'away_player_Y7',
#  'away_player_Y8',
#  'away_player_Y9',
#  'away_player_Y10',
#  'away_player_Y11',
#  'home_player_1',
#  'home_player_2',
#  'home_player_3',
#  'home_player_4',
#  'home_player_5',
#  'home_player_6',
#  'home_player_7',
#  'home_player_8',
#  'home_player_9',
#  'home_player_10',
#  'home_player_11',
#  'away_player_1',
#  'away_player_2',
#  'away_player_3',
#  'away_player_4',
#  'away_player_5',
#  'away_player_6',
#  'away_player_7',
#  'away_player_8',
#  'away_player_9',
#  'away_player_10',
#  'away_player_11',
#  'goal',
#  'shoton',
#  'shotoff',
#  'foulcommit',
#  'card',
#  'cross',
#  'corner',
#  'possession',
#  'B365H',
#  'B365D',
#  'B365A',
#  'BWH',
#  'BWD',
#  'BWA',
#  'IWH',
#  'IWD',
#  'IWA',
#  'LBH',
#  'LBD',
#  'LBA',
#  'PSH',
#  'PSD',
#  'PSA',
#  'WHH',
#  'WHD',
#  'WHA',
#  'SJH',
#  'SJD',
#  'SJA',
#  'VCH',
#  'VCD',
#  'VCA',
#  'GBH',
#  'GBD',
#  'GBA',
#  'BSH',
#  'BSD',
#  'BSA']

# %%
#Faire une somme d'une colonne
match = pd.read_sql("""SELECT SUM(home_team_goal),SUM(away_team_goal)
                        FROM match;""", conn)
match
# Out:
#    SUM(home_team_goal)  SUM(away_team_goal)
# 0                40127                30160

# %%
#compter nombre de lignes dans une colonne ou dans une table
match = pd.read_sql("""SELECT COUNT(*)
                        FROM match;""", conn)
match
# Out:
#    COUNT(*)
# 0     25979

# %%
#compter nombre de lignes dans une colonne ou dans une table avec filtre
match = pd.read_sql("""SELECT COUNT(*)
                        FROM match
                        WHERE home_team_goal > 2;""", conn)
match
# Out:
#    COUNT(*)
# 0      5344

# %%
#Trouver le maximum d'une colonne
match = pd.read_sql("""SELECT MAX(home_team_goal),MAX(away_team_goal)
                        FROM match;""", conn)
match
# Out:
#    MAX(home_team_goal)  MAX(away_team_goal)
# 0                   10                    9

# %%
#Faire une moyenne
match = pd.read_sql("""SELECT AVG(home_team_goal),AVG(away_team_goal)
                        FROM match;""", conn)
match
# Out:
#    AVG(home_team_goal)  AVG(away_team_goal)
# 0             1.544594             1.160938

# %%
#Grouper les données via une dimension
match = pd.read_sql("""SELECT season, AVG(home_team_goal),AVG(away_team_goal)
                        FROM match
                        GROUP BY season;""", conn)
match
# Out:
#       season  AVG(home_team_goal)  AVG(away_team_goal)
# 0  2008/2009             1.505412             1.101924
# 1  2009/2010             1.541176             1.131269
# 2  2010/2011             1.548466             1.135276
# 3  2011/2012             1.572671             1.143789
# 4  2012/2013             1.550000             1.222699
# 5  2013/2014             1.578826             1.187995
# 6  2014/2015             1.520301             1.155489
# 7  2015/2016             1.543897             1.210764

# %%
#renommer les variables avec les alias
match = pd.read_sql("""SELECT AVG(home_team_goal) AS Moyenne_buts_domicile,AVG(away_team_goal) AS Moyenne_buts_exterieur
                        FROM match
                        GROUP BY season;""", conn)
match
# Out:
#    Moyenne_buts_domicile  Moyenne_buts_exterieur
# 0               1.505412                1.101924
# 1               1.541176                1.131269
# 2               1.548466                1.135276
# 3               1.572671                1.143789
# 4               1.550000                1.222699
# 5               1.578826                1.187995
# 6               1.520301                1.155489
# 7               1.543897                1.210764

# %%
#Faire des filtres sur des alias
match = pd.read_sql("""SELECT season, SUM(home_team_goal) AS Moyenne_buts_domicile,SUM(away_team_goal) AS Moyenne_buts_exterieur
                        FROM match
                        GROUP BY season
                        WHERE Moyenne_buts_domicile > 5000;""", conn)
match
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1680         try:
# -> 1681             cur.execute(*args, **kwargs)
#    1682             return cur
#
# OperationalError: near "WHERE": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-30-c657ae2976f2> in <module>
#       1 #Faire des filtres sur des alias
# ----> 2 match = pd.read_sql("""SELECT season, SUM(home_team_goal) AS Moyenne_buts_domicile,SUM(away_team_goal) AS Moyenne_buts_exterieur
#       3                         FROM match
#       4                         GROUP BY season
#       5                         WHERE Moyenne_buts_domicile > 5000;""", conn)
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     481
#     482     if isinstance(pandas_sql, SQLiteDatabase):
# --> 483         return pandas_sql.read_query(
#     484             sql,
#     485             index_col=index_col,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1725
#    1726         args = _convert_params(sql, params)
# -> 1727         cursor = self.execute(*args)
#    1728         columns = [col_desc[0] for col_desc in cursor.description]
#    1729
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1691
#    1692             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 1693             raise ex from exc
#    1694
#    1695     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT season, SUM(home_team_goal) AS Moyenne_buts_domicile,SUM(away_team_goal) AS Moyenne_buts_exterieur
#                         FROM match
#                         GROUP BY season
#                         WHERE Moyenne_buts_domicile > 5000;': near "WHERE": syntax error

# %%
#Faire des filtres sur des alias
match = pd.read_sql("""SELECT season, SUM(home_team_goal) AS Moyenne_buts_domicile,SUM(away_team_goal) AS Moyenne_buts_exterieur
                        FROM match
                        GROUP BY season
                        HAVING Moyenne_buts_domicile > 5000;""", conn)
match
# Out:
#       season  Moyenne_buts_domicile  Moyenne_buts_exterieur
# 0  2008/2009                   5007                    3665
# 1  2010/2011                   5048                    3701
# 2  2011/2012                   5064                    3683
# 3  2012/2013                   5053                    3986
# 4  2014/2015                   5055                    3842
# 5  2015/2016                   5135                    4027

# %%
#Avoir des infos sur une table
infos = pd.read_sql("""PRAGMA table_info(match);""", conn)
infos
# Out:
#      cid        name     type  notnull dflt_value  pk
# 0      0          id  INTEGER        0       None   1
# 1      1  country_id  INTEGER        0       None   0
# 2      2   league_id  INTEGER        0       None   0
# 3      3      season     TEXT        0       None   0
# 4      4       stage  INTEGER        0       None   0
# ..   ...         ...      ...      ...        ...  ..
# 110  110         GBD  NUMERIC        0       None   0
# 111  111         GBA  NUMERIC        0       None   0
# 112  112         BSH  NUMERIC        0       None   0
# 113  113         BSD  NUMERIC        0       None   0
# 114  114         BSA  NUMERIC        0       None   0
#
# [115 rows x 6 columns]

# %%
#concept de clé primaire (primary key) et de clé étrangère (foreign key)
match = pd.read_sql("""SELECT *
                        FROM match;""", conn)
match
# Out:
#           id  country_id  league_id     season  stage                 date  \
# 0          1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1          2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2          3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3          4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4          5           1          1  2008/2009      1  2008-08-16 00:00:00
# ...      ...         ...        ...        ...    ...                  ...
# 25974  25975       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25975  25976       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25976  25977       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25977  25978       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25978  25979       24558      24558  2015/2016      9  2015-09-23 00:00:00
#
#        match_api_id  home_team_api_id  away_team_api_id  home_team_goal  ...  \
# 0            492473              9987              9993               1  ...
# 1            492474             10000              9994               0  ...
# 2            492475              9984              8635               0  ...
# 3            492476              9991              9998               5  ...
# 4            492477              7947              9985               1  ...
# ...             ...               ...               ...             ...  ...
# 25974       1992091             10190             10191               1  ...
# 25975       1992092              9824             10199               1  ...
# 25976       1992093              9956             10179               2  ...
# 25977       1992094              7896             10243               0  ...
# 25978       1992095             10192              9931               4  ...
#
#         SJA   VCH   VCD   VCA   GBH   GBD   GBA   BSH   BSD   BSA
# 0      4.00  1.65  3.40  4.50  1.78  3.25  4.00  1.73  3.40  4.20
# 1      3.80  2.00  3.25  3.25  1.85  3.25  3.75  1.91  3.25  3.60
# 2      2.50  2.35  3.25  2.65  2.50  3.20  2.50  2.30  3.20  2.75
# 3      7.50  1.45  3.75  6.50  1.50  3.75  5.50  1.44  3.75  6.50
# 4      1.73  4.50  3.40  1.65  4.50  3.50  1.65  4.75  3.30  1.67
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 25974   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25975   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25976   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25977   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25978   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [25979 rows x 115 columns]

# %%
infos = pd.read_sql("""PRAGMA table_info(Country);""", conn)
infos
# Out:
#    cid  name     type  notnull dflt_value  pk
# 0    0    id  INTEGER        0       None   1
# 1    1  name     TEXT        0       None   0

# %%
countries = pd.read_sql("""SELECT *
                        FROM Country ;""", conn)
countries
# Out:
#        id         name
# 0       1      Belgium
# 1    1729      England
# 2    4769       France
# 3    7809      Germany
# 4   10257        Italy
# 5   13274  Netherlands
# 6   15722       Poland
# 7   17642     Portugal
# 8   19694     Scotland
# 9   21518        Spain
# 10  24558  Switzerland

# %% [markdown]
# ![primay_key.PNG](attachment:primay_key.PNG)

# %%
#faire une jointure entre 2 tables
match = pd.read_sql("""SELECT country.*,* FROM MATCH
                        INNER JOIN country
                        ON match.country_id == country.id;""", conn)
match
# Out:
#           id         name     id  country_id  league_id     season  stage  \
# 0          1      Belgium      1           1          1  2008/2009      1
# 1          1      Belgium      2           1          1  2008/2009      1
# 2          1      Belgium      3           1          1  2008/2009      1
# 3          1      Belgium      4           1          1  2008/2009      1
# 4          1      Belgium      5           1          1  2008/2009      1
# ...      ...          ...    ...         ...        ...        ...    ...
# 25974  24558  Switzerland  25975       24558      24558  2015/2016      9
# 25975  24558  Switzerland  25976       24558      24558  2015/2016      9
# 25976  24558  Switzerland  25977       24558      24558  2015/2016      9
# 25977  24558  Switzerland  25978       24558      24558  2015/2016      9
# 25978  24558  Switzerland  25979       24558      24558  2015/2016      9
#
#                       date  match_api_id  home_team_api_id  ...   VCD   VCA  \
# 0      2008-08-17 00:00:00        492473              9987  ...  3.40  4.50
# 1      2008-08-16 00:00:00        492474             10000  ...  3.25  3.25
# 2      2008-08-16 00:00:00        492475              9984  ...  3.25  2.65
# 3      2008-08-17 00:00:00        492476              9991  ...  3.75  6.50
# 4      2008-08-16 00:00:00        492477              7947  ...  3.40  1.65
# ...                    ...           ...               ...  ...   ...   ...
# 25974  2015-09-22 00:00:00       1992091             10190  ...   NaN   NaN
# 25975  2015-09-23 00:00:00       1992092              9824  ...   NaN   NaN
# 25976  2015-09-23 00:00:00       1992093              9956  ...   NaN   NaN
# 25977  2015-09-22 00:00:00       1992094              7896  ...   NaN   NaN
# 25978  2015-09-23 00:00:00       1992095             10192  ...   NaN   NaN
#
#         GBH   GBD   GBA   BSH   BSD   BSA     id         name
# 0      1.78  3.25  4.00  1.73  3.40  4.20      1      Belgium
# 1      1.85  3.25  3.75  1.91  3.25  3.60      1      Belgium
# 2      2.50  3.20  2.50  2.30  3.20  2.75      1      Belgium
# 3      1.50  3.75  5.50  1.44  3.75  6.50      1      Belgium
# 4      4.50  3.50  1.65  4.75  3.30  1.67      1      Belgium
# ...     ...   ...   ...   ...   ...   ...    ...          ...
# 25974   NaN   NaN   NaN   NaN   NaN   NaN  24558  Switzerland
# 25975   NaN   NaN   NaN   NaN   NaN   NaN  24558  Switzerland
# 25976   NaN   NaN   NaN   NaN   NaN   NaN  24558  Switzerland
# 25977   NaN   NaN   NaN   NaN   NaN   NaN  24558  Switzerland
# 25978   NaN   NaN   NaN   NaN   NaN   NaN  24558  Switzerland
#
# [25979 rows x 119 columns]

# %%
#Selectionner uniquement certaines tables 
match = pd.read_sql("""SELECT home_team_api_id,away_team_api_id,home_team_goal,away_team_goal, country.name FROM MATCH
                        INNER JOIN country
                        ON match.country_id == country.id;""", conn)
match
# Out:
#        home_team_api_id  away_team_api_id  home_team_goal  away_team_goal  \
# 0                  9987              9993               1               1
# 1                 10000              9994               0               0
# 2                  9984              8635               0               3
# 3                  9991              9998               5               0
# 4                  7947              9985               1               3
# ...                 ...               ...             ...             ...
# 25974             10190             10191               1               0
# 25975              9824             10199               1               2
# 25976              9956             10179               2               0
# 25977              7896             10243               0               0
# 25978             10192              9931               4               3
#
#               name
# 0          Belgium
# 1          Belgium
# 2          Belgium
# 3          Belgium
# 4          Belgium
# ...            ...
# 25974  Switzerland
# 25975  Switzerland
# 25976  Switzerland
# 25977  Switzerland
# 25978  Switzerland
#
# [25979 rows x 5 columns]

# %%
team = pd.read_sql("""SELECT *
                        FROM team;""", conn)
team
# Out:
#         id  team_api_id  team_fifa_api_id      team_long_name team_short_name
# 0        1         9987             673.0            KRC Genk             GEN
# 1        2         9993             675.0        Beerschot AC             BAC
# 2        3        10000           15005.0    SV Zulte-Waregem             ZUL
# 3        4         9994            2007.0    Sporting Lokeren             LOK
# 4        5         9984            1750.0   KSV Cercle Brugge             CEB
# ..     ...          ...               ...                 ...             ...
# 294  49479        10190             898.0       FC St. Gallen             GAL
# 295  49837        10191            1715.0             FC Thun             THU
# 296  50201         9777             324.0         Servette FC             SER
# 297  50204         7730            1862.0  FC Lausanne-Sports             LAU
# 298  51606         7896               NaN              Lugano             LUG
#
# [299 rows x 5 columns]

# %%
#Les jointures multiples
match = pd.read_sql("""SELECT team.team_long_name,away_team_api_id,home_team_goal,away_team_goal, country.name FROM MATCH
                        INNER JOIN country ON match.country_id == country.id
                        INNER JOIN team ON match.home_team_api_id == team.team_api_id;""", conn)
match
# Out:
#                 team_long_name  away_team_api_id  home_team_goal  \
# 0                     KRC Genk              9993               1
# 1             SV Zulte-Waregem              9994               0
# 2            KSV Cercle Brugge              8635               0
# 3                     KAA Gent              9998               5
# 4                FCV Dender EH              9985               1
# ...                        ...               ...             ...
# 25974            FC St. Gallen             10191               1
# 25975                 FC Vaduz             10199               1
# 25976  Grasshopper Club Zürich             10179               2
# 25977                   Lugano             10243               0
# 25978           BSC Young Boys              9931               4
#
#        away_team_goal         name
# 0                   1      Belgium
# 1                   0      Belgium
# 2                   3      Belgium
# 3                   0      Belgium
# 4                   3      Belgium
# ...               ...          ...
# 25974               0  Switzerland
# 25975               2  Switzerland
# 25976               0  Switzerland
# 25977               0  Switzerland
# 25978               3  Switzerland
#
# [25979 rows x 5 columns]

# %%
#Les jointures multiples sur une même table
match = pd.read_sql("""SELECT tHome.team_long_name,tAway.team_long_name,home_team_goal,away_team_goal, country.name FROM MATCH
                        INNER JOIN country ON match.country_id == country.id
                        INNER JOIN team tHome ON match.home_team_api_id == tHome.team_api_id
                        INNER JOIN team tAway ON match.away_team_api_id == tAway.team_api_id;""", conn)
match
# Out:
#                 team_long_name     team_long_name  home_team_goal  \
# 0                     KRC Genk       Beerschot AC               1
# 1             SV Zulte-Waregem   Sporting Lokeren               0
# 2            KSV Cercle Brugge     RSC Anderlecht               0
# 3                     KAA Gent          RAEC Mons               5
# 4                FCV Dender EH  Standard de Liège               1
# ...                        ...                ...             ...
# 25974            FC St. Gallen            FC Thun               1
# 25975                 FC Vaduz          FC Luzern               1
# 25976  Grasshopper Club Zürich            FC Sion               2
# 25977                   Lugano          FC Zürich               0
# 25978           BSC Young Boys           FC Basel               4
#
#        away_team_goal         name
# 0                   1      Belgium
# 1                   0      Belgium
# 2                   3      Belgium
# 3                   0      Belgium
# 4                   3      Belgium
# ...               ...          ...
# 25974               0  Switzerland
# 25975               2  Switzerland
# 25976               0  Switzerland
# 25977               0  Switzerland
# 25978               3  Switzerland
#
# [25979 rows x 5 columns]

# %%
#Les jointures multiples avec Alias
match = pd.read_sql("""SELECT tHome.team_long_name AS equipe_domicile,tAway.team_long_name AS equipe_exterieur,home_team_goal,away_team_goal, country.name FROM MATCH
                        INNER JOIN country ON match.country_id == country.id
                        INNER JOIN team AS tHome ON match.home_team_api_id == tHome.team_api_id
                        INNER JOIN team AS tAway ON match.away_team_api_id == tAway.team_api_id;""", conn)
match

# %%
#Les jointures multiples avec filtres
match = pd.read_sql("""SELECT tHome.team_long_name AS equipe_domicile,tAway.team_long_name AS equipe_exterieur,home_team_goal,away_team_goal, country.name FROM MATCH
                        INNER JOIN country ON match.country_id == country.id
                        INNER JOIN team AS tHome ON match.home_team_api_id == tHome.team_api_id
                        INNER JOIN team AS tAway ON match.away_team_api_id == tAway.team_api_id
                        WHERE country.name == 'France' AND home_team_goal > 2;""", conn)
match
# Out:
#            equipe_domicile        equipe_exterieur  home_team_goal  \
# 0       Olympique Lyonnais             Toulouse FC               3
# 1         Stade Rennais FC  Olympique de Marseille               4
# 2               FC Lorient               FC Nantes               3
# 3    Girondins de Bordeaux             Le Havre AC               4
# 4                AS Monaco       AS Nancy-Lorraine               3
# ..                     ...                     ...             ...
# 481    Paris Saint-Germain    En Avant de Guingamp               3
# 482              SC Bastia             Toulouse FC               3
# 483  Girondins de Bordeaux      Olympique Lyonnais               3
# 484   En Avant de Guingamp               AS Monaco               3
# 485             FC Lorient   Girondins de Bordeaux               3
#
#      away_team_goal    name
# 0                 0  France
# 1                 4  France
# 2                 0  France
# 3                 0  France
# 4                 1  France
# ..              ...     ...
# 481               0  France
# 482               0  France
# 483               1  France
# 484               3  France
# 485               2  France
#
# [486 rows x 5 columns]

# %% [markdown]
# Les autres types de jointures
# ![join.PNG](attachment:join.PNG)
